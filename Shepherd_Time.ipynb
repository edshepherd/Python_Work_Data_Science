# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
from datetime import datetime

# %%
df = pd.read_csv("/Users/burrisfaculty/Desktop/DSCode/CS621/Homework 5 Data/DailyDelhiClimateTrain.csv", parse_dates = True, index_col = 0)

# %%
df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df['meantemp'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df['wind_speed'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df['humidity'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.loc['2015']['wind_speed'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.wind_speed.plot()
df.wind_speed.rolling(window = 60).mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.meantemp.plot()
df.meantemp.rolling(window = 30).min().plot()
df.meantemp.rolling(window = 30).mean().plot()
df.meantemp.rolling(window = 30).max().plot()
# Out:
# <AxesSubplot:xlabel='date'>
